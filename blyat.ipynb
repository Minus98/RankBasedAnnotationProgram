# %%
import nibabel as nib
import numpy as np
from PIL import Image

import matplotlib.pyplot as plt

# %%
l = nib.load("C:/Users/Hanna/Documents/Repos/RankBasedAnnotationProgram/niiImgSet/1.nii")
print(l.header)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  3 512 512 108   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [-1.         0.8203125  0.8203125  3.         0.         0.
#   0.         0.       ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b'Time=91352.000'
# aux_file        : b''
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.0
# ...

# %%
test_load = nib.load("C:/Users/Hanna/Documents/Repos/RankBasedAnnotationProgram/niiImgSet/1.nii").get_fdata()[:, :, 50] + 1024

# %%
np_im = np.array(test_load, dtype="uint32")
im = Image.fromarray(np_im)
im.show()

# %%
#test = test_load[:,:,55]
plt.imshow(test_load)
plt.show()

# %%
for i in range(10):
    plt.subplot(5, 5, i + 1)
    plt.imshow(test_load[:,:,i*10])
    plt.gcf().set_size_inches(10, 10)
plt.show()
