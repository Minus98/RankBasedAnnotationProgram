# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# %%
test_load = nib.load('niiImgSet\CTlungaFantom3mm.nii').get_fdata()
test_load.shape
# Out:
# (512, 512, 108)

# %%
test = test_load[:,:,55]
plt.imshow(test)
plt.show()

# %%
for i in range(10):
    plt.subplot(5, 5, i + 1)
    plt.imshow(test_load[:,:,i*10])
    plt.gcf().set_size_inches(10, 10)
plt.show()
